# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # House Price Prediction - EDA
#
# This project analyzes the House Prices dataset from Kaggle.

# %%
df = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ### 📌 Dataset Overview
#
# - The dataset contains house features and sale prices.
# - It includes both numerical and categorical variables.
# - Target variable: **SalePrice**

# %%
df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing.head(10)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# MasVnrType      872
# FireplaceQu     690
# LotFrontage     259
# GarageYrBlt      81
# GarageCond       81
# GarageType       81
# dtype: int64

# %% [markdown]
# ### 📌 Missing Values
#
# - Some features contain missing values.
# - These will be handled during data preprocessing.

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
cat_cols = df.select_dtypes(include=["object"]).columns

len(num_cols), len(cat_cols)
# Out:
# /var/folders/h_/10cl5rt94plc4dhs3qdszndw0000gn/T/ipykernel_2243/388907867.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=["object"]).columns
# (38, 43)

# %% [markdown]
# ### 📌 Feature Types
#
# - Numerical features: used for correlation analysis.
# - Categorical features: used for grouping and comparisons.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
corr = df.corr(numeric_only=True)["SalePrice"].sort_values(ascending=False)
corr.head(10)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### 📌 Correlation Analysis
#
# - We analyze how features relate to SalePrice.
# - Strong correlations indicate important predictors.

# %%
corr.head(10).plot(kind="barh")
plt.title("Top Correlated Features with SalePrice")
plt.show()

# %%
df[num_cols].hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x="MSZoning", y="SalePrice", data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 📌 Categorical Features Analysis
#
# - We analyze how categories affect house prices.
# - Some categories clearly influence price differences.

# %%
for col in df.columns:
    print("🔹 Feature:", col)
    print(df[col].describe())
    print(df[col].value_counts().head())
    print("\n------------------------\n")
# Out:
# 🔹 Feature: Id
# count    1460.000000
# mean      730.500000
# std       421.610009
# min         1.000000
# 25%       365.750000
# 50%       730.500000
# 75%      1095.250000
# max      1460.000000
# Name: Id, dtype: float64
# Id
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64
#
# ------------------------
#
# 🔹 Feature: MSSubClass
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# Name: count, dtype: int64
#
# ------------------------
#
# 🔹 Feature: MSZoning
# count     1460
# unique       5
# top         RL
# freq      1151
# Name: MSZoning, dtype: object
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# ------------------------
#
# ...

# %%
important_cols = ["OverallQual", "GrLivArea", "GarageCars", "TotalBsmtSF", "1stFlrSF"]

for col in important_cols:
    sns.scatterplot(x=df[col], y=df["SalePrice"])
    plt.title(f"{col} vs SalePrice")
    plt.show()

# %%
cat_cols = df.select_dtypes(include="object").columns

for col in cat_cols[:5]:  # ilk 5 yeterli (yoksa çok uzun olur)
    sns.boxplot(x=df[col], y=df["SalePrice"])
    plt.xticks(rotation=45)
    plt.title(col)
    plt.show()
# Out:
# /var/folders/h_/10cl5rt94plc4dhs3qdszndw0000gn/T/ipykernel_2243/1955708141.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include="object").columns

# %%
# drop high missing
df = df.drop(columns=["PoolQC", "MiscFeature", "Alley", "Fence"])

# categorical fill
cat_cols = df.select_dtypes(include="object").columns
for col in cat_cols:
    df[col] = df[col].fillna("None")

# numerical fill
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())
# Out:
# /var/folders/h_/10cl5rt94plc4dhs3qdszndw0000gn/T/ipykernel_2243/2253981941.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include="object").columns

# %%
df["TotalSF"] = df["TotalBsmtSF"] + df["1stFlrSF"] + df["2ndFlrSF"]
df["HouseAge"] = 2024 - df["YearBuilt"]
df["RemodAge"] = 2024 - df["YearRemodAdd"]
